# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv(r"D:\DATA SCIENCE\column_transformer\credit_scoring - credit_scoring.csv")

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler, OneHotEncoder
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 from sklearn.compose import ColumnTransformer
#       2 from sklearn.preprocessing import StandardScaler, OneHotEncoder
#
# ModuleNotFoundError: No module named 'sklearn'

# %%
num = df.select_dtypes(exclude="object")
cat=df.select_dtypes(include="object")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 num = df.select_dtypes(exclude="object")
#       2 cat=df.select_dtypes(include="object")
#
# NameError: name 'df' is not defined

# %%
preprocessor = ColumnTransformer(
    transformers=[
        ("num", StandardScaler(), num),
        ("cat", OneHotEncoder(drop='first', sparse_output=False), cat)
    ]
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 preprocessor = ColumnTransformer(
#       2     transformers=[
#       3         ("num", StandardScaler(), num),
#       4         ("cat", OneHotEncoder(drop='first', sparse_output=False), cat)
#       5     ]
#       6 )
#
# NameError: name 'ColumnTransformer' is not defined

# %%
preprocessor
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 preprocessor
#
# NameError: name 'preprocessor' is not defined
